# %% [markdown]
# <a href="https://colab.research.google.com/github/Mal-Lem/Pandas-pour-DS/blob/main/4_data_modeling_avec_Pandas_Exercice_%C3%A9l%C3%A8ve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Exercice</h1>
#
# Vous travaillez pour une société de distribution de films. Vous avez un DataFrame movies qui contient des données sur les sorties de films les plus rentables. Vous devez filtrer, trier et transformer ces données pour préparer votre analyse.
#
# <b>Énoncé de l'Exercice</b>
#
# Avec le DataFrame movies, réalisez les opérations suivantes en utilisant pandas :
# 1) Filtrez et affichez les films dont le total des recettes (Total Gross) dépasse 800 millions de dollars.
# 2) Filtrez et affichez les films dont le nom contient le mot "Star".
# 3) Filtrez et affichez les films qui appartiennent aux distributeurs 'Warner Bros.' ou 'Universal Pictures'.
# 4) Utilisez une combinaison de filtres pour sélectionner les films sortis après le 01-01-2015 (> '2015-01-01') avec une note (% of Total) supérieure à 30%.
# 5) Filtrez les films par leur note en utilisant .query() pour ceux ayant une note entre 25% et 35% inclus.
# 6) Identifiez les films sortis après 2010 qui ont une recette moyenne par salle supérieure à la médiane de tous les films.
# 7) Triez les films par leur Total Gross en ordre décroissant.
# 8) Triez les films par leur Date de sortie en ordre ascendant, en gérant correctement les valeurs manquantes.
# 9) Effectuez un tri multicritères : d'abord par Distributor (ordre alphabétique) puis par Opening en ordre décroissant.
# 10) Trier les films par la longueur de leur nom (Release) en utilisant une fonction de clé personnalisée qui trie les films par le nombre de caractères, en ordre décroissant.
# 11) Créez une nouvelle colonne 'Revenue per Theater' en divisant Total Gross par Theaters.
# 12) créez une nouvelle colonne 'Is Blockbuster' qui marque 'Yes' pour les films avec plus de 40% de Total Gross et 'No' pour les autres.
# 13) Ajoutez une colonne 'Profitability' calculée comme le rapport (division) entre le Total Gross et Opening. Cela peut servir à évaluer l'endurance du film au box-office après le week-end d'ouverture.
# 14) Créez une nouvelle colonne 'Genre' en utilisant la méthode .map() avec une fonction qui assigne 'Action' aux films avec le mot 'War' ou 'Battle' dans leur titre, 'Adventure' pour les films avec 'Star' ou 'Journey', et 'Other' pour tous les autres films.
# 15) Enregristrez le dataframe dans un csv 'Top_Highest_Openings_Modeled.csv'

# %%
import pandas as pd

movies = pd.read_csv('Top_Highest_Openings.csv')
movies['Date'] = pd.to_datetime(movies['Date'], dayfirst=True)

movies.head(3)
# Out:
#                    Release    Opening  Total Gross  % of Total  Theaters  \
# 0        Avengers: Endgame  357115007    858373000        41.6      4662
# 1  Spider-Man: No Way Home  260138569    804793477        32.3      4336
# 2   Avengers: Infinity War  257698183    678815482        38.0      4474
#
#    Average       Date                          Distributor
# 0    76601 2019-04-26  Walt Disney Studios Motion Pictures
# 1    59995 2021-12-17              Sony Pictures Releasing
# 2    57599 2018-04-27  Walt Disney Studios Motion Pictures

# %%
# 1. Filtrez par Total Gross > 800M
df_filtered1 = movies[movies['Total Gross'] > 800000000]
df_filtered1
# Out:
#                                       Release    Opening  Total Gross  \
# 0                           Avengers: Endgame  357115007    858373000
# 1                     Spider-Man: No Way Home  260138569    804793477
# 3  Star Wars: Episode VII - The Force Awakens  247966675    936662225
#
#    % of Total  Theaters  Average       Date  \
# 0        41.6      4662    76601 2019-04-26
# 1        32.3      4336    59995 2021-12-17
# 3        26.5      4134    59982 2015-12-18
#
#                            Distributor
# 0  Walt Disney Studios Motion Pictures
# 1              Sony Pictures Releasing
# 3  Walt Disney Studios Motion Pictures

# %%
# 2. Filtrez par nom contenant "Star"
df_filtered2 = movies[movies['Release'].str.contains('Star',case = False)]
df_filtered2
# Out:
#                                                Release    Opening  \
# 3           Star Wars: Episode VII - The Force Awakens  247966675
# 4              Star Wars: Episode VIII - The Last Jedi  220009584
# 14       Star Wars: Episode IX - The Rise of Skywalker  177383864
# 23                        Rogue One: A Star Wars Story  155081681
# 62        Star Wars: Episode III - Revenge of the Sith  108435841
# 108                            Solo: A Star Wars Story   84420489
# 116       Star Wars: Episode II - Attack of the Clones   80027814
# 128                                          Star Trek   75204289
# 150                            Star Trek Into Darkness   70165559
# 181          Star Wars: Episode I - The Phantom Menace   64820970
# 206                                   Star Trek Beyond   59253211
# 300                             The Fault in Our Stars   48002523
# 360                                     A Star Is Born   42908051
# 473  Star Wars: Episode IV - A New Hope1997 Special...   35906661
# 589                           Star Trek: First Contact   30716131
# 687                                    Starsky & Hutch   28103367
# 892                             Star Trek: Generations   23116394
# 897         Star Wars: Episode VI - Return of the Jedi   23019618
# 928  Star Wars: Episode I - The Phantom Menace2012 ...   22469932
# 950                                  Starship Troopers   22058773
# 951                            Star Trek: Insurrection   22052836
# 955  Star Wars: Episode V - The Empire Strikes Back...   21975993
#
#      Total Gross  % of Total  Theaters  Average       Date  \
# 3      936662225        26.5      4134    59982 2015-12-18
# 4      620181382        35.5      4232    51987 2017-12-15
# 14     515202542        34.4      4406    40259 2019-12-20
# 23     532177324        29.1      4157    37306 2016-12-16
# 62     380270577        28.5      3661    29619 2005-05-19
# 108    213767512        39.5      4381    19269 2018-05-25
# 116    302191252        26.5      3161    25317 2002-05-16
# 128    257730019        29.2      3849    19538 2009-05-08
# 150    228778661        30.7      3868    18140 2013-05-16
# 181    431088295        15.0      2970    21825 1999-05-19
# 206    158848340        37.3      3928    15084 2016-07-22
# 300    124872350        38.4      3173    15128 2014-06-06
# 360    215288866        19.9      3686    11640 2018-10-05
# 473    138257865        26.0      2104    17065 1997-01-31
# 589     92027888        33.4      2812    10923 1996-11-22
# 687     88237754        31.8      3185     8823 2004-03-05
# 892     75671125        30.6      2659     8693 1994-11-18
# 897    252583617         9.1      1002    22973 1983-05-25
# 928     43456382        51.7      2655     8463 2012-02-10
# 950     54814377        40.2      2971     7424 1997-11-07
# 951     70187658        31.4      2620     8417 1998-12-11
# 955     67597694        32.5      2111    10410 1997-02-21
#
#                              Distributor
# 3    Walt Disney Studios Motion Pictures
# 4    Walt Disney Studios Motion Pictures
# 14   Walt Disney Studios Motion Pictures
# 23   Walt Disney Studios Motion Pictures
# 62                 Twentieth Century Fox
# 108  Walt Disney Studios Motion Pictures
# 116                Twentieth Century Fox
# 128                   Paramount Pictures
# 150                   Paramount Pictures
# 181                Twentieth Century Fox
# 206                   Paramount Pictures
# 300                Twentieth Century Fox
# 360                         Warner Bros.
# 473                Twentieth Century Fox
# 589                   Paramount Pictures
# 687                         Warner Bros.
# 892                   Paramount Pictures
# 897                Twentieth Century Fox
# 928                Twentieth Century Fox
# 950              Sony Pictures Releasing
# 951                   Paramount Pictures
# 955                Twentieth Century Fox

# %%
# 3. Filtrez par distributeur
df_filtered3 = movies[movies['Distributor'].isin(['Warner Bros.','Universal Pictures'])]
df_filtered3
# Out:
#                                           Release    Opening  Total Gross  \
# 5                                  Jurassic World  208806270    652270625
# 17   Harry Potter and the Deathly Hallows: Part 2  169189427    381011219
# 18             Batman v Superman: Dawn of Justice  166007347    330360194
# 19                                         Barbie  162022044    636238421
# 20                          The Dark Knight Rises  160887295    448139099
# ..                                            ...        ...          ...
# 984                                         Tammy   21577049     84525432
# 986                            You, Me and Dupree   21525560     75628110
# 988                              American Reunion   21514080     57011521
# 990                        The 40-Year-Old Virgin   21422815    109449237
# 992                                     Good Boys   21402605     83140306
#
#      % of Total  Theaters  Average       Date         Distributor
# 5          32.0      4274    48855 2015-06-12  Universal Pictures
# 17         44.4      4375    38671 2011-07-15        Warner Bros.
# 18         50.2      4242    39134 2016-03-25        Warner Bros.
# 19         25.5      4243    38185 2023-07-21        Warner Bros.
# 20         35.9      4404    36532 2012-07-20        Warner Bros.
# ..          ...       ...      ...        ...                 ...
# 984        25.5      3465     6227 2014-07-02        Warner Bros.
# 986        28.5      3131     6874 2006-07-14  Universal Pictures
# 988        37.7      3192     6740 2012-04-06  Universal Pictures
# 990        19.6      2845     7529 2005-08-19  Universal Pictures
# 992        25.7      3204     6679 2019-08-16  Universal Pictures
#
# [327 rows x 8 columns]

# %%
# 4. Combinaison de filtres pour % of Total et Date
df_filtered4 = movies[(movies['% of Total'] > 30) & (movies['Date'] > '2015-01-01')]
df_filtered4
# Out:
#                                      Release    Opening  Total Gross  \
# 0                          Avengers: Endgame  357115007    858373000
# 1                    Spider-Man: No Way Home  260138569    804793477
# 2                     Avengers: Infinity War  257698183    678815482
# 4    Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# 5                             Jurassic World  208806270    652270625
# ..                                       ...        ...          ...
# 966             Neighbors 2: Sorority Rising   21760405     55455765
# 975                               Lights Out   21688103     67268835
# 980                        London Has Fallen   21635601     62524260
# 996                         Angel Has Fallen   21380987     69030436
# 997                Ice Age: Collision Course   21373064     64063008
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 4          35.5      4232    51987 2017-12-15
# 5          32.0      4274    48855 2015-06-12
# ..          ...       ...      ...        ...
# 966        39.2      3384     6430 2016-05-20
# 975        32.2      2818     7696 2016-07-22
# 980        34.6      3490     6199 2016-03-04
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
#
#                              Distributor
# 0    Walt Disney Studios Motion Pictures
# 1                Sony Pictures Releasing
# 2    Walt Disney Studios Motion Pictures
# 4    Walt Disney Studios Motion Pictures
# 5                     Universal Pictures
# ..                                   ...
# 966                   Universal Pictures
# 975                         Warner Bros.
# 980                       Focus Features
# 996                      Lionsgate Films
# 997                Twentieth Century Fox
#
# [213 rows x 8 columns]

# %%
# 5. Filtrez par note avec .query()
df_filtered5 = movies.query('(`% of Total` > 25) & (`% of Total` <= 35)')
df_filtered5
# Out:
#                                         Release    Opening  Total Gross  \
# 1                       Spider-Man: No Way Home  260138569    804793477
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 5                                Jurassic World  208806270    652270625
# 6                                  The Avengers  207438708    623357910
# 7                                 Black Panther  202003951    700059566
# ..                                          ...        ...          ...
# 993                                  Safe Haven   21401594     71349120
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average       Date  \
# 1          32.3      4336    59995 2021-12-17
# 3          26.5      4134    59982 2015-12-18
# 5          32.0      4274    48855 2015-06-12
# 6          33.3      4349    47698 2012-05-04
# 7          28.9      4020    50249 2018-02-16
# ..          ...       ...      ...        ...
# 993        30.0      3223     6640 2013-02-14
# 995        28.3      3377     6332 2017-08-18
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
# 999        25.7      3806     5599 2013-07-17
#
#                              Distributor
# 1                Sony Pictures Releasing
# 3    Walt Disney Studios Motion Pictures
# 5                     Universal Pictures
# 6    Walt Disney Studios Motion Pictures
# 7    Walt Disney Studios Motion Pictures
# ..                                   ...
# 993                     Relativity Media
# 995                      Lionsgate Films
# 996                      Lionsgate Films
# 997                Twentieth Century Fox
# 999                Twentieth Century Fox
#
# [403 rows x 8 columns]

# %%
# 6. films sortis après 2010 qui ont une recette moyenne par salle supérieure à la médiane de tous les films
df_filtered6 = movies[(movies['Date'].dt.year > 2010) & (movies['Total Gross'] > movies['Total Gross'].median())]
df_filtered6
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 870                        Mary Poppins Returns   23523121    171958438
# 885        Alvin and the Chipmunks: Chipwrecked   23244744    133110742
# 929                                  Life of Pi   22451514    124987023
# 936                                      Sing 2   22326230    162790990
# 978                                   Bumblebee   21654047    127195589
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 3          26.5      4134    59982 2015-12-18
# 4          35.5      4232    51987 2017-12-15
# ..          ...       ...      ...        ...
# 870        13.7      4090     5751 2018-12-19
# 885        17.5      3723     6243 2011-12-16
# 929        18.0      2927     7670 2012-11-21
# 936        13.7      3892     5736 2021-12-22
# 978        17.0      3550     6099 2018-12-21
#
#                              Distributor
# 0    Walt Disney Studios Motion Pictures
# 1                Sony Pictures Releasing
# 2    Walt Disney Studios Motion Pictures
# 3    Walt Disney Studios Motion Pictures
# 4    Walt Disney Studios Motion Pictures
# ..                                   ...
# 870  Walt Disney Studios Motion Pictures
# 885                Twentieth Century Fox
# 929                Twentieth Century Fox
# 936                   Universal Pictures
# 978                   Paramount Pictures
#
# [256 rows x 8 columns]

# %%
# 7. Tri par Total Gross
df_filtered7 = movies.sort_values(by='Total Gross', ascending=False)
df_filtered7
# Out:
#                                                Release    Opening  \
# 3           Star Wars: Episode VII - The Force Awakens  247966675
# 0                                    Avengers: Endgame  357115007
# 1                              Spider-Man: No Way Home  260138569
# 124                                             Avatar   77025481
# 44                                   Top Gun: Maverick  126707459
# ..                                                 ...        ...
# 741                                     All Eyez on Me   26435354
# 928  Star Wars: Episode I - The Phantom Menace2012 ...   22469932
# 880                                      Mortal Kombat   23302503
# 969                                     Texas Chainsaw   21744470
# 963                     Renaissance: A Film by Beyoncé   21801216
#
#      Total Gross  % of Total  Theaters  Average       Date  \
# 3      936662225        26.5      4134    59982 2015-12-18
# 0      858373000        41.6      4662    76601 2019-04-26
# 1      804793477        32.3      4336    59995 2021-12-17
# 124    749766139        10.3      3452    22313 2009-12-18
# 44     718732821        17.6      4735    26759 2022-05-27
# ..           ...         ...       ...      ...        ...
# 741     44922302        58.8      2471    10698 2017-06-16
# 928     43456382        51.7      2655     8463 2012-02-10
# 880     42326031        55.0      3073     7582 2021-04-23
# 969     34341945        63.3      2654     8193 2013-01-04
# 963     33889684        64.3      2539     8586 2023-12-01
#
#                              Distributor
# 3    Walt Disney Studios Motion Pictures
# 0    Walt Disney Studios Motion Pictures
# 1                Sony Pictures Releasing
# 124                Twentieth Century Fox
# 44                    Paramount Pictures
# ..                                   ...
# 741                      Lionsgate Films
# 928                Twentieth Century Fox
# 880                         Warner Bros.
# 969                      Lionsgate Films
# 963                                    -
#
# [1000 rows x 8 columns]

# %%
# 8. Tri par Date avec gestion des NaN
df_filtered8 = movies.sort_values(by='Date', ascending=True, na_position='first')
df_filtered8
# Out:
#                                         Release   Opening  Total Gross  \
# 897  Star Wars: Episode VI - Return of the Jedi  23019618    252583617
# 782        Indiana Jones and the Temple of Doom  25337110    179870271
# 746                        Beverly Hills Cop II  26348555    153665036
# 647          Indiana Jones and the Last Crusade  29355021    197171806
# 645                             Ghostbusters II  29472894    112494738
# ..                                          ...       ...          ...
# 671                        Bob Marley: One Love  28659004     96456635
# 111                              Dune: Part Two  82505391    264858587
# 214                             Kung Fu Panda 4  57989905    158207090
# 337                 Ghostbusters: Frozen Empire  45004673     88863665
# 117             Godzilla x Kong: The New Empire  80006561    135037630
#
#      % of Total  Theaters  Average       Date              Distributor
# 897         9.1      1002    22973 1983-05-25    Twentieth Century Fox
# 782        14.1      1687    15019 1984-05-23       Paramount Pictures
# 746        17.2      2326    11327 1987-05-20       Paramount Pictures
# 647        14.9      2327    12614 1989-05-24       Paramount Pictures
# 645        26.2      2410    12229 1989-06-16        Columbia Pictures
# ..          ...       ...      ...        ...                      ...
# 671        29.7      3539     8098 2024-02-14       Paramount Pictures
# 111        31.2      4071    20266 2024-03-01             Warner Bros.
# 214        36.6      4035    14371 2024-03-08       Universal Pictures
# 337        50.6      4345    10357 2024-03-22  Sony Pictures Releasing
# 117        59.2      3861    20721 2024-03-29             Warner Bros.
#
# [1000 rows x 8 columns]

# %%
# 9. Tri multicritères par Distributor et Opening
df_filtered9 = movies.sort_values(by=['Distributor', 'Opening'], ascending=[True, False])
df_filtered9
# Out:
#                             Release    Opening  Total Gross  % of Total  \
# 84      Taylor Swift: The Eras Tour   93224755    180756269        51.6
# 402                   Scary Movie 4   40222875     90710620        44.3
# 745                       Halloween   26362367     58272029        45.2
# 963  Renaissance: A Film by Beyoncé   21801216     33889684        64.3
# 38         Avatar: The Way of Water  134100226    684075767        19.6
# ..                              ...        ...          ...         ...
# 972                     Cats & Dogs   21707617     93385515        23.2
# 973                  Eyes Wide Shut   21706163     55691208        39.0
# 975                      Lights Out   21688103     67268835        32.2
# 983                     Fool's Gold   21589295     70231041        30.7
# 984                           Tammy   21577049     84525432        25.5
#
#      Theaters  Average       Date           Distributor
# 84       3855    24182 2023-10-13                     -
# 402      3602    11166 2006-04-14                     -
# 745      3472     7592 2007-08-31                     -
# 963      2539     8586 2023-12-01                     -
# 38       4202    31913 2022-12-16  20th Century Studios
# ..        ...      ...        ...                   ...
# 972      3040     7140 2001-07-04          Warner Bros.
# 973      2411     9002 1999-07-16          Warner Bros.
# 975      2818     7696 2016-07-22          Warner Bros.
# 983      3125     6908 2008-02-08          Warner Bros.
# 984      3465     6227 2014-07-02          Warner Bros.
#
# [1000 rows x 8 columns]

# %%
# 10. Trier les films par la longueur de leur nom (Release)
df_filtered10 = movies.sort_values(by='Release', key=lambda x: x.str.len(), ascending=False)
df_filtered10
# Out:
#                                                Release    Opening  \
# 955  Star Wars: Episode V - The Empire Strikes Back...   21975993
# 176  The Chronicles of Narnia: The Lion, the Witch ...   65556312
# 579  Hannah Montana and Miley Cyrus: Best of Both W...   31117834
# 848  The Chronicles of Narnia: The Voyage of the Da...   24005069
# 928  Star Wars: Episode I - The Phantom Menace2012 ...   22469932
# ..                                                 ...        ...
# 160                                                 Up   68108790
# 141                                                 Us   71117625
# 103                                                 X2   85558731
# 708                                                 42   27487144
# 47                                                  It  123403419
#
#      Total Gross  % of Total  Theaters  Average       Date  \
# 955     67597694        32.5      2111    10410 1997-02-21
# 176    291710957        22.5      3616    18129 2005-12-09
# 579     65281781        47.7       683    45560 2008-02-01
# 848    104386950        23.0      3555     6752 2010-12-10
# 928     43456382        51.7      2655     8463 2012-02-10
# ..           ...         ...       ...      ...        ...
# 160    293004164        23.2      3766    18085 2009-05-29
# 141    175084580        40.6      3741    19010 2019-03-22
# 103    214949694        39.8      3741    22870 2003-05-02
# 708     95020213        28.9      3003     9153 2013-04-12
# 47     327481748        37.7      4103    30076 2017-09-08
#
#                              Distributor
# 955                Twentieth Century Fox
# 176  Walt Disney Studios Motion Pictures
# 579  Walt Disney Studios Motion Pictures
# 848                Twentieth Century Fox
# 928                Twentieth Century Fox
# ..                                   ...
# 160  Walt Disney Studios Motion Pictures
# 141                   Universal Pictures
# 103                Twentieth Century Fox
# 708                         Warner Bros.
# 47                          Warner Bros.
#
# [1000 rows x 8 columns]

# %%
# 11. Nouvelle colonne Revenue per Theater
df_filtered11= movies.assign(Revenue_per_Theater=movies['Total Gross'] / movies['Theaters'])
df_filtered11
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 998                      Why Did I Get Married?   21353789     55204525
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 3          26.5      4134    59982 2015-12-18
# 4          35.5      4232    51987 2017-12-15
# ..          ...       ...      ...        ...
# 995        28.3      3377     6332 2017-08-18
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
# 998        38.7      2011    10618 2007-10-12
# 999        25.7      3806     5599 2013-07-17
#
#                              Distributor  Revenue_per_Theater
# 0    Walt Disney Studios Motion Pictures        184121.192621
# 1                Sony Pictures Releasing        185607.351707
# 2    Walt Disney Studios Motion Pictures        151724.515422
# 3    Walt Disney Studios Motion Pictures        226575.284228
# 4    Walt Disney Studios Motion Pictures        146545.695180
# ..                                   ...                  ...
# 995                      Lionsgate Films         22347.818478
# 996                      Lionsgate Films         21007.436397
# 997                Twentieth Century Fox         16047.847695
# 998                      Lionsgate Films         27451.280457
# 999                Twentieth Century Fox         21815.062533
#
# [1000 rows x 9 columns]

# %%
# 12. Nouvelle colonne Is Blockbuster avec .map()
df_filtered12 = movies.assign(Is_Blockbuster=movies['Total Gross'].map(lambda x: 'Yes' if x > 40 else 'No'))
df_filtered12
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 998                      Why Did I Get Married?   21353789     55204525
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 3          26.5      4134    59982 2015-12-18
# 4          35.5      4232    51987 2017-12-15
# ..          ...       ...      ...        ...
# 995        28.3      3377     6332 2017-08-18
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
# 998        38.7      2011    10618 2007-10-12
# 999        25.7      3806     5599 2013-07-17
#
#                              Distributor Is_Blockbuster
# 0    Walt Disney Studios Motion Pictures            Yes
# 1                Sony Pictures Releasing            Yes
# 2    Walt Disney Studios Motion Pictures            Yes
# 3    Walt Disney Studios Motion Pictures            Yes
# 4    Walt Disney Studios Motion Pictures            Yes
# ..                                   ...            ...
# 995                      Lionsgate Films            Yes
# 996                      Lionsgate Films            Yes
# 997                Twentieth Century Fox            Yes
# 998                      Lionsgate Films            Yes
# 999                Twentieth Century Fox            Yes
#
# [1000 rows x 9 columns]

# %%
# 13. colonne 'Profitability' calculée comme le rapport entre le Total Gross et Opening
df_filtered13 = movies.assign(Profitability=movies['Total Gross'] / movies['Opening'])
df_filtered13
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 998                      Why Did I Get Married?   21353789     55204525
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 3          26.5      4134    59982 2015-12-18
# 4          35.5      4232    51987 2017-12-15
# ..          ...       ...      ...        ...
# 995        28.3      3377     6332 2017-08-18
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
# 998        38.7      2011    10618 2007-10-12
# 999        25.7      3806     5599 2013-07-17
#
#                              Distributor  Profitability
# 0    Walt Disney Studios Motion Pictures       2.403632
# 1                Sony Pictures Releasing       3.093711
# 2    Walt Disney Studios Motion Pictures       2.634149
# 3    Walt Disney Studios Motion Pictures       3.777371
# 4    Walt Disney Studios Motion Pictures       2.818883
# ..                                   ...            ...
# 995                      Lionsgate Films       3.529125
# 996                      Lionsgate Films       3.228590
# 997                Twentieth Century Fox       2.997371
# 998                      Lionsgate Films       2.585233
# 999                Twentieth Century Fox       3.895725
#
# [1000 rows x 9 columns]

# %%
# 14. Créez une nouvelle colonne 'Genre'
# Créez une nouvelle colonne 'Genre' en utilisant la méthode .map() avec une fonction qui assigne 'Action' aux films avec le mot 'War'
# ou 'Battle' dans leur titre, 'Adventure' pour les films avec 'Star' ou 'Journey', et 'Other' pour tous les autres films.
df_filtred14 = movies.assign(Genre=movies['Release'].map(lambda x : 'Action' if 'War' in x or 'Battle' in x else 'Adventure' if 'Star' in x or 'Journey' in x else 'Other'))
df_filtred14
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 998                      Why Did I Get Married?   21353789     55204525
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average       Date  \
# 0          41.6      4662    76601 2019-04-26
# 1          32.3      4336    59995 2021-12-17
# 2          38.0      4474    57599 2018-04-27
# 3          26.5      4134    59982 2015-12-18
# 4          35.5      4232    51987 2017-12-15
# ..          ...       ...      ...        ...
# 995        28.3      3377     6332 2017-08-18
# 996        31.0      3286     6506 2019-08-23
# 997        33.4      3992     5353 2016-07-22
# 998        38.7      2011    10618 2007-10-12
# 999        25.7      3806     5599 2013-07-17
#
#                              Distributor   Genre
# 0    Walt Disney Studios Motion Pictures   Other
# 1                Sony Pictures Releasing   Other
# 2    Walt Disney Studios Motion Pictures  Action
# 3    Walt Disney Studios Motion Pictures  Action
# 4    Walt Disney Studios Motion Pictures  Action
# ..                                   ...     ...
# 995                      Lionsgate Films   Other
# 996                      Lionsgate Films   Other
# 997                Twentieth Century Fox   Other
# 998                      Lionsgate Films   Other
# 999                Twentieth Century Fox   Other
#
# [1000 rows x 9 columns]

# %%
# 15. enregistrement
save = df_filtred14.to_csv('Top_Highest_Openings_Modeled.csv', index=False)
