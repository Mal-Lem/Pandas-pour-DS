# %% [markdown]
# <a href="https://colab.research.google.com/github/Mal-Lem/Pandas-pour-DS/blob/main/Atelier_1_Netflix_%C3%A9nonc%C3%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Exercice </h1>
#
# Le dataset "Titres Netflix" est une compilation exhaustive de films et de séries télévisées disponibles sur Netflix, couvrant divers aspects tels que le type de titre, le réalisateur, les acteurs, le pays de production, l'année de sortie, la classification, la durée, les genres (répertoriés dans) et une brève description. Ce dataset est essentiel pour analyser les tendances du contenu Netflix, comprendre la popularité des genres et examiner la distribution du contenu à travers différentes régions et périodes.
#
# Les colonnes :
# - show_id : Un identifiant unique pour chaque titre.
# - type : La catégorie du titre, qui peut être 'Film' ou 'Série télévisée'.
# - title : Le nom du film ou de la série télévisée.
# - director : Le(s) réalisateur(s) du film ou de la série télévisée. (Contient des valeurs nulles pour certaines entrées, en particulier les séries télévisées où cette information peut ne pas être applicable.)
# - cast : La liste des acteurs principaux du titre. (Certaines entrées peuvent ne pas avoir cette information.)
# - country : Le pays ou les pays où le film ou la série télévisée a été produit.
# - date_added : La date à laquelle le titre a été ajouté à Netflix.
# - release_year : L'année de sortie originale du film ou de la série télévisée.
# - rating : La classification par âge du titre.
# - duration : La durée du titre, en minutes pour les films et en saisons pour les séries télévisées.
# - listed_in : Les genres auxquels appartient le titre.
# - description : Un bref résumé du titre.
#
# <h1> Enoncé </h1>
#
# <h2> data cleaning & data modeling </h2>
#
# <b> 1) Importation du fichier </b>
#
# Tentez d'importer le fichier netflix_titles.csv. Si vous rencontrez une erreur, celle-ci est probablement liée à un problème d'encodage. Trouvez l'encodage adéquat pour lire le fichier correctement.
#
# <b> 2) Création d'une copie du DataFrame </b>
#
# Créez une copie de votre DataFrame dans une nouvelle variable afin de conserver les données originales accessibles.
#
# <b> 3) Suppression des colonnes inutiles </b>
#
# Vérifiez que les colonnes nommées "Unnamed:..." en fin de DataFrame ne contiennent aucune donnée, puis supprimez-les.
#
# <b> 4) Définition d'un nouvel index </b>
#
# Assurez-vous que la colonne "Show_id" ne possède ni valeur nulle ni doublon. Si c'est le cas, définissez show_id comme index du DataFrame.
#
# <b> 5) Correction du type de colonne </b>
# Vérifiez le type de la colonne "Date_added" et corrigez-le avec le type adéquat si nécessaire.
#
# <b> 6) Gestion de la colonne "Duration" </b>
#
# - Confirmez que la colonne "Type" contient uniquement les valeurs 'Movie' et 'TV Show'.
# - Examinez la nomenclature des valeurs de la colonne "Duration".
# - Via un groupby, vérifiez que les durées sont bien associées à une durée en minutes pour les films et à un nombre de saisons pour les séries.
# - Créez une nouvelle colonne 'duration (movies)' pour isoler le nombre de minutes pour les films. Assurez-vous que cette  colonne soit de type "float".
# - Créez une colonne 'seasons (TV Show)' pour isoler le nombre de saisons pour les séries. Assurez-vous que cette colonne soit de type "float".
# - Supprimez finalement la colonne 'Duration' du dataset.
#
# <b> 7) Création de DataFrames annexes pour les valeurs séparées par des virgules </b>
#
# Certaines colonnes comme country, cast et listed_in contiennent pour certains titres des séries de valeurs, sépérées par des virgules. Nous souhaitons créer des tableaux annexes permettant d'avoir chaque valeur de manière distincte.
#
# Pour la colonne "Country" :
# - Créez une colonne 'countries' en transformant les valeurs de la colonne 'country' en listes (via str.split).
# - Créez un DataFrame 'countries_exploded' qui génère une ligne pour chaque pays via la méthode .explode().
# - Isolez uniquement la colonne 'countries' dans le DataFrame 'countries_exploded' (non vue en cours, à vous de comprendre son fonctionnement : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html)
# - Répétez ce processus pour les colonnes 'categories' (basée sur 'listed_in') et 'cast', créant respectivement les - DataFrames 'categories_exploded' et 'cast_list'.
#
# <b> 8) Suppression des colonnes transformées </b>
#
# Supprimez les trois colonnes transformées du DataFrame original.
#
# <b> 9) Création de colonnes temporelles </b>
#
# À partir de 'Date Added', créez des colonnes pour l'année d'ajout, le mois d'ajout et le jour de la semaine d'ajout.
# Analyse des Données
#
# <h2> Analyse des données </h2>
#
# Tentez maintenant de répondre aux questions suivantes :
#
# 1) Combien de "shows" sont présents dans ce dataset ?
# 2) Quelle est la répartition entre les types 'Movie' et 'TV Show' ?
# 3) Quelle est la répartition des ajouts en fonction de l'année ?
# 4) Quel est le top 5 des catégories de shows les plus ajoutées ?
# 5) Quel est le top 5 des comédiens les plus plébiscités aux États-Unis ?
# 6) Quelle est la répartition des ajouts en fonction du jour de la semaine ?
# 7) Dans quel pays sont produits le plus de documentaires ?
# 8) En moyenne, combien de saisons ont les séries ?
# 9) Quelle est la distribution des films en fonction de leur durée (quartiles) ?
# 10) Combien de shows ont pour thématique la drogue (présence du mot "drug" dans la description) ?

# %% [markdown]
# <h1> Data Cleaning et data modeling</h1>

# %% [markdown]
# ### Importation du fichier

# %%
import pandas as pd

url = '/content/netflix_titles.csv'
data = pd.read_csv(url,encoding='iso-8859-1')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# 1  September 24, 2021          2021  TV-MA  2 Seasons  ...         NaN
# 2  September 24, 2021          2021  TV-MA   1 Season  ...         NaN
# 3  September 24, 2021          2021  TV-MA   1 Season  ...         NaN
# 4  September 24, 2021          2021  TV-MA  2 Seasons  ...         NaN
#
#   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Création d'une copie du DataFrame

# %%
df = pd.DataFrame(data)
df_copy = df.copy()
df_copy.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  ... Unnamed: 16  \
# 0  September 25, 2021          2020  PG-13     90 min  ...         NaN
# 1  September 24, 2021          2021  TV-MA  2 Seasons  ...         NaN
# 2  September 24, 2021          2021  TV-MA   1 Season  ...         NaN
# 3  September 24, 2021          2021  TV-MA   1 Season  ...         NaN
# 4  September 24, 2021          2021  TV-MA  2 Seasons  ...         NaN
#
#   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Suppression des colonnes inutiles

# %%
df.columns.str.contains('Unnamed')
df.drop(df.columns[df.columns.str.contains('Unnamed')],axis=1,inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Définition d'un nouvel index

# %%
df['show_id'].isna().sum()
df['show_id'].duplicated().sum()
df.set_index('show_id',inplace=True)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %% [markdown]
# ### Correction du type de colonne

# %%
df['date_added'].dtypes
df['date_added'] = pd.to_datetime(df['date_added'],format='%B %d, %Y',errors='coerce')
df['date_added'].dtype
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating   duration  \
# show_id
# s1      2021-09-25          2020  PG-13     90 min
# s2      2021-09-24          2021  TV-MA  2 Seasons
# s3      2021-09-24          2021  TV-MA   1 Season
# s4      2021-09-24          2021  TV-MA   1 Season
# s5      2021-09-24          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %% [markdown]
# ### Gestion de la colonne "Duration"
#
#   Confirmez que la colonne "Type" contient uniquement les valeurs 'Movie'
#
# et 'TV Show'.
#   Examinez la nomenclature des valeurs de la colonne "Duration".
#   Via un groupby, vérifiez que les durées sont bien associées à une durée en minutes pour les films et à un nombre de saisons pour les séries.
#   Créez une nouvelle colonne 'duration (movies)' pour isoler le nombre de minutes pour les films. Assurez-vous que cette colonne soit de type "float".
#   Créez une colonne 'seasons (TV Show)' pour isoler le nombre de saisons pour les séries. Assurez-vous que cette colonne soit de type "float".
#   Supprimez finalement la colonne 'Duration' du dataset

# %%
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
#        '140 min', '78 min', '7 Seasons', '64 min', '59 min', '139 min',
#        '69 min', '148 min', '189 min', '141 min', '130 min', '138 min',
#        '81 min', '132 min', '10 Seasons', '123 min', '65 min', '68 min',
#        '66 min', '62 min', '74 min', '131 min', '39 min', '46 min',
#        '38 min', '8 Seasons', '17 Seasons', '126 min', '155 min',
#        '159 min', '137 min', '12 min', '273 min', '36 min', '34 min',
#        '77 min', '60 min', '49 min', '58 min', '72 min', '204 min',
#        '212 min', '25 min', '73 min', '29 min', '47 min', '32 min',
#        '35 min', '71 min', '149 min', '33 min', '15 min', '54 min',
#        '224 min', '162 min', '37 min', '75 min', '79 min', '55 min',
#        '158 min', '164 min', '173 min', '181 min', '185 min', '21 min',
#        '24 min', '51 min', '151 min', '42 min', '22 min', '134 min',
#        '177 min', '13 Seasons', '52 min', '14 min', '53 min', '8 min',
#        '57 min', '28 min', '50 min', '9 min', '26 min', '45 min',
#        '171 min', '27 min', '44 min', '146 min', '20 min', '157 min',
#        '17 min', '203 min', '41 min', '30 min', '194 min', '15 Seasons',
#        '233 min', '237 min', '230 min', '195 min', '253 min', '152 min',
#        '190 min', '160 min', '208 min', '180 min', '144 min', '5 min',
#        '174 min', '170 min', '192 min', '209 min', '187 min', '172 min',
#        '16 min', '186 min', '11 min', '193 min', '176 min', '56 min',
#        '169 min', '40 min', '10 min', '3 min', '168 min', '312 min',
#        '153 min', '214 min', '31 min', '163 min', '19 min', '12 Seasons',
#        nan, '179 min', '11 Seasons', '43 min', '200 min', '196 min',
#        '167 min', '178 min', '228 min', '18 min', '205 min', '201 min',
#        '191 min'], dtype=object)

# %%
df.groupby('type')['duration'].unique()
# Out:
# type
# Movie      [90 min, 91 min, 125 min, 104 min, 127 min, 67...
# TV Show    [2 Seasons, 1 Season, 9 Seasons, 4 Seasons, 5 ...
# Name: duration, dtype: object

# %%
# extraire les minutes pour les films
df['duration (movies)'] = df.apply(
    lambda row: float(str(row['duration']).split()[0]) if row['type'] == 'Movie' else None,
    axis=1
)

# extraire les saisons pour les séries
df['seasons (TV Show)'] = df.apply(
    lambda row: float(str(row['duration']).split()[0]) if row['type'] == 'TV Show' else None,
    axis=1
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8809 entries, s1 to s8809
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               8809 non-null   object
#  1   title              8809 non-null   object
#  2   director           6175 non-null   object
#  3   cast               7984 non-null   object
#  4   country            7978 non-null   object
#  5   date_added         8711 non-null   datetime64[ns]
#  6   release_year       8809 non-null   int64
#  7   rating             8805 non-null   object
#  8   duration           8806 non-null   object
#  9   listed_in          8809 non-null   object
#  10  description        8809 non-null   object
#  11  duration (movies)  6129 non-null   float64
#  12  seasons (TV Show)  2677 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 963.5+ KB

# %%
df.drop('duration',axis=1,inplace=True)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating  \
# show_id
# s1      2021-09-25          2020  PG-13
# s2      2021-09-24          2021  TV-MA
# s3      2021-09-24          2021  TV-MA
# s4      2021-09-24          2021  TV-MA
# s5      2021-09-24          2021  TV-MA
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s5       In a city of coaching centers known to train I...                NaN
#
#          seasons (TV Show)
# show_id
# s1                     NaN
# s2                     2.0
# s3                     1.0
# s4                     1.0
# s5                     2.0

# %% [markdown]
# ### Création de DataFrames annexes pour les valeurs séparées par des virgules
#
# Certaines colonnes comme country, cast et listed_in contiennent pour certains titres des séries de valeurs, sépérées par des virgules. Nous souhaitons créer des tableaux annexes permettant d'avoir chaque valeur de manière distincte.
#
# Pour la colonne "Country" :
#
#   Créez une colonne 'countries' en transformant les valeurs de la colonne 'country' en listes (via str.split).
#   Créez un DataFrame 'countries_exploded' qui génère une ligne pour chaque pays via la méthode .explode().
#   Isolez uniquement la colonne 'countries' dans le DataFrame 'countries_exploded' (non vue en cours, à vous de comprendre son fonctionnement : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html)
#   Répétez ce processus pour les colonnes 'categories' (basée sur 'listed_in') et 'cast', créant respectivement les - DataFrames 'categories_exploded' et 'cast_list'.

# %%
df['country'] = df['country'].str.split(',')
countries_exploded = df.explode('country')
countries_exploded.head(20)
# Out:
#             type                                title  \
# show_id
# s1         Movie                 Dick Johnson Is Dead
# s2       TV Show                        Blood & Water
# s3       TV Show                            Ganglands
# s4       TV Show                Jailbirds New Orleans
# s5       TV Show                         Kota Factory
# s6       TV Show                        Midnight Mass
# s7         Movie     My Little Pony: A New Generation
# s8         Movie                              Sankofa
# s8         Movie                              Sankofa
# s8         Movie                              Sankofa
# s8         Movie                              Sankofa
# s8         Movie                              Sankofa
# s8         Movie                              Sankofa
# s9       TV Show        The Great British Baking Show
# s10        Movie                         The Starling
# s11      TV Show  Vendetta: Truth, Lies and The Mafia
# s12      TV Show                     Bangkok Breaking
# s13        Movie                         Je Suis Karl
# s13        Movie                         Je Suis Karl
# s14        Movie     Confessions of an Invisible Girl
#
#                                director  \
# show_id
# s1                      Kirsten Johnson
# s2                                  NaN
# s3                      Julien Leclercq
# s4                                  NaN
# s5                                  NaN
# s6                        Mike Flanagan
# s7       Robert Cullen, JosÃ© Luis Ucha
# s8                         Haile Gerima
# s8                         Haile Gerima
# s8                         Haile Gerima
# s8                         Haile Gerima
# s8                         Haile Gerima
# s8                         Haile Gerima
# s9                      Andy Devonshire
# s10                      Theodore Melfi
# s11                                 NaN
# s12                   Kongkiat Komesiri
# s13                 Christian Schwochow
# s13                 Christian Schwochow
# s14                       Bruno Garotti
#
#                                                       cast          country  \
# show_id
# s1                                                     NaN    United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...              NaN
# s4                                                     NaN              NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            India
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...              NaN
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...              NaN
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...    United States
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...            Ghana
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...     Burkina Faso
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...   United Kingdom
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...          Germany
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...         Ethiopia
# s9       Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...   United Kingdom
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...    United States
# s11                                                    NaN              NaN
# s12      Sukollawat Kanarot, Sushar Manaying, Pavarit M...              NaN
# s13      Luna Wedler, Jannis NiewÃ¶hner, Milan Peschel,...          Germany
# s13      Luna Wedler, Jannis NiewÃ¶hner, Milan Peschel,...   Czech Republic
# s14      Klara Castanho, Lucca Picon, JÃºlia Gomes, Mar...              NaN
#
#         date_added  release_year rating  \
# show_id
# s1      2021-09-25          2020  PG-13
# s2      2021-09-24          2021  TV-MA
# s3      2021-09-24          2021  TV-MA
# s4      2021-09-24          2021  TV-MA
# s5      2021-09-24          2021  TV-MA
# s6      2021-09-24          2021  TV-MA
# s7      2021-09-24          2021     PG
# s8      2021-09-24          1993  TV-MA
# s8      2021-09-24          1993  TV-MA
# s8      2021-09-24          1993  TV-MA
# s8      2021-09-24          1993  TV-MA
# s8      2021-09-24          1993  TV-MA
# s8      2021-09-24          1993  TV-MA
# s9      2021-09-24          2021  TV-14
# s10     2021-09-24          2021  PG-13
# s11     2021-09-24          2021  TV-MA
# s12     2021-09-23          2021  TV-MA
# s13     2021-09-23          2021  TV-MA
# s13     2021-09-23          2021  TV-MA
# s14     2021-09-22          2021  TV-PG
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# s6                      TV Dramas, TV Horror, TV Mysteries
# s7                                Children & Family Movies
# s8        Dramas, Independent Movies, International Movies
# s8        Dramas, Independent Movies, International Movies
# s8        Dramas, Independent Movies, International Movies
# s8        Dramas, Independent Movies, International Movies
# s8        Dramas, Independent Movies, International Movies
# s8        Dramas, Independent Movies, International Movies
# s9                            British TV Shows, Reality TV
# s10                                       Comedies, Dramas
# s11      Crime TV Shows, Docuseries, International TV S...
# s12      Crime TV Shows, International TV Shows, TV Act...
# s13                           Dramas, International Movies
# s13                           Dramas, International Movies
# s14                     Children & Family Movies, Comedies
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s5       In a city of coaching centers known to train I...                NaN
# s6       The arrival of a charismatic young priest brin...                NaN
# s7       Equestria's divided. But a bright-eyed hero be...               91.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s9       A talented batch of amateur bakers face off in...                NaN
# s10      A woman adjusting to life after a loss contend...              104.0
# s11      Sicily boasts a bold "Anti-Mafia" coalition. B...                NaN
# s12      Struggling to earn a living in Bangkok, a man ...                NaN
# s13      After most of her family is murdered in a terr...              127.0
# s13      After most of her family is murdered in a terr...              127.0
# s14      When the clever but socially-awkward TetÃª joi...               91.0
#
#          seasons (TV Show)
# show_id
# s1                     NaN
# s2                     2.0
# s3                     1.0
# s4                     1.0
# s5                     2.0
# s6                     1.0
# s7                     NaN
# s8                     NaN
# s8                     NaN
# s8                     NaN
# s8                     NaN
# s8                     NaN
# s8                     NaN
# s9                     9.0
# s10                    NaN
# s11                    1.0
# s12                    1.0
# s13                    NaN
# s13                    NaN
# s14                    NaN

# %%
df['listed_in'] = df['listed_in'].str.split(',')
df.head(20)
categories_exploded = df.explode('listed_in')
categories_exploded.head(20)
# Out:
#             type                             title  \
# show_id
# s1         Movie              Dick Johnson Is Dead
# s2       TV Show                     Blood & Water
# s2       TV Show                     Blood & Water
# s2       TV Show                     Blood & Water
# s3       TV Show                         Ganglands
# s3       TV Show                         Ganglands
# s3       TV Show                         Ganglands
# s4       TV Show             Jailbirds New Orleans
# s4       TV Show             Jailbirds New Orleans
# s5       TV Show                      Kota Factory
# s5       TV Show                      Kota Factory
# s5       TV Show                      Kota Factory
# s6       TV Show                     Midnight Mass
# s6       TV Show                     Midnight Mass
# s6       TV Show                     Midnight Mass
# s7         Movie  My Little Pony: A New Generation
# s8         Movie                           Sankofa
# s8         Movie                           Sankofa
# s8         Movie                           Sankofa
# s9       TV Show     The Great British Baking Show
#
#                                director  \
# show_id
# s1                      Kirsten Johnson
# s2                                  NaN
# s2                                  NaN
# s2                                  NaN
# s3                      Julien Leclercq
# s3                      Julien Leclercq
# s3                      Julien Leclercq
# s4                                  NaN
# s4                                  NaN
# s5                                  NaN
# s5                                  NaN
# s5                                  NaN
# s6                        Mike Flanagan
# s6                        Mike Flanagan
# s6                        Mike Flanagan
# s7       Robert Cullen, JosÃ© Luis Ucha
# s8                         Haile Gerima
# s8                         Haile Gerima
# s8                         Haile Gerima
# s9                      Andy Devonshire
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                     NaN
# s4                                                     NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s9       Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                                    country date_added  \
# show_id
# s1                                         [United States] 2021-09-25
# s2                                          [South Africa] 2021-09-24
# s2                                          [South Africa] 2021-09-24
# s2                                          [South Africa] 2021-09-24
# s3                                                     NaN 2021-09-24
# s3                                                     NaN 2021-09-24
# s3                                                     NaN 2021-09-24
# s4                                                     NaN 2021-09-24
# s4                                                     NaN 2021-09-24
# s5                                                 [India] 2021-09-24
# s5                                                 [India] 2021-09-24
# s5                                                 [India] 2021-09-24
# s6                                                     NaN 2021-09-24
# s6                                                     NaN 2021-09-24
# s6                                                     NaN 2021-09-24
# s7                                                     NaN 2021-09-24
# s8       [United States,  Ghana,  Burkina Faso,  United... 2021-09-24
# s8       [United States,  Ghana,  Burkina Faso,  United... 2021-09-24
# s8       [United States,  Ghana,  Burkina Faso,  United... 2021-09-24
# s9                                        [United Kingdom] 2021-09-24
#
#          release_year rating                 listed_in  \
# show_id
# s1               2020  PG-13             Documentaries
# s2               2021  TV-MA    International TV Shows
# s2               2021  TV-MA                 TV Dramas
# s2               2021  TV-MA              TV Mysteries
# s3               2021  TV-MA            Crime TV Shows
# s3               2021  TV-MA    International TV Shows
# s3               2021  TV-MA     TV Action & Adventure
# s4               2021  TV-MA                Docuseries
# s4               2021  TV-MA                Reality TV
# s5               2021  TV-MA    International TV Shows
# s5               2021  TV-MA         Romantic TV Shows
# s5               2021  TV-MA               TV Comedies
# s6               2021  TV-MA                 TV Dramas
# s6               2021  TV-MA                 TV Horror
# s6               2021  TV-MA              TV Mysteries
# s7               2021     PG  Children & Family Movies
# s8               1993  TV-MA                    Dramas
# s8               1993  TV-MA        Independent Movies
# s8               1993  TV-MA      International Movies
# s9               2021  TV-14          British TV Shows
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s5       In a city of coaching centers known to train I...                NaN
# s5       In a city of coaching centers known to train I...                NaN
# s5       In a city of coaching centers known to train I...                NaN
# s6       The arrival of a charismatic young priest brin...                NaN
# s6       The arrival of a charismatic young priest brin...                NaN
# s6       The arrival of a charismatic young priest brin...                NaN
# s7       Equestria's divided. But a bright-eyed hero be...               91.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s8       On a photo shoot in Ghana, an American model s...              125.0
# s9       A talented batch of amateur bakers face off in...                NaN
#
#          seasons (TV Show)
# show_id
# s1                     NaN
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s3                     1.0
# s3                     1.0
# s3                     1.0
# s4                     1.0
# s4                     1.0
# s5                     2.0
# s5                     2.0
# s5                     2.0
# s6                     1.0
# s6                     1.0
# s6                     1.0
# s7                     NaN
# s8                     NaN
# s8                     NaN
# s8                     NaN
# s9                     9.0

# %%
df['cast'] = df['cast'].str.split(',')
cast_list = df.explode('cast')
cast_list.head(20)
# Out:
#             type                 title         director  \
# show_id
# s1         Movie  Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
# s2       TV Show         Blood & Water              NaN
#
#                           cast          country date_added  release_year  \
# show_id
# s1                         NaN  [United States] 2021-09-25          2020
# s2                  Ama Qamata   [South Africa] 2021-09-24          2021
# s2                 Khosi Ngema   [South Africa] 2021-09-24          2021
# s2               Gail Mabalane   [South Africa] 2021-09-24          2021
# s2              Thabang Molaba   [South Africa] 2021-09-24          2021
# s2            Dillon Windvogel   [South Africa] 2021-09-24          2021
# s2             Natasha Thahane   [South Africa] 2021-09-24          2021
# s2                 Arno Greeff   [South Africa] 2021-09-24          2021
# s2           Xolile Tshabalala   [South Africa] 2021-09-24          2021
# s2             Getmore Sithole   [South Africa] 2021-09-24          2021
# s2              Cindy Mahlangu   [South Africa] 2021-09-24          2021
# s2               Ryle De Morny   [South Africa] 2021-09-24          2021
# s2             Greteli Fincham   [South Africa] 2021-09-24          2021
# s2        Sello Maake Ka-Ncube   [South Africa] 2021-09-24          2021
# s2                 Odwa Gwanya   [South Africa] 2021-09-24          2021
# s2              Mekaila Mathys   [South Africa] 2021-09-24          2021
# s2               Sandi Schultz   [South Africa] 2021-09-24          2021
# s2              Duane Williams   [South Africa] 2021-09-24          2021
# s2             Shamilla Miller   [South Africa] 2021-09-24          2021
# s2            Patrick Mofokeng   [South Africa] 2021-09-24          2021
#
#         rating                                          listed_in  \
# show_id
# s1       PG-13                                    [Documentaries]
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
# s2       TV-MA  [International TV Shows,  TV Dramas,  TV Myste...
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s2       After crossing paths at a party, a Cape Town t...                NaN
#
#          seasons (TV Show)
# show_id
# s1                     NaN
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0
# s2                     2.0

# %% [markdown]
# ### 8) Suppression des colonnes transformées
#
# Supprimez les trois colonnes transformées du DataFrame original.

# %%
df.drop(['country','listed_in','cast'],axis=1,inplace=True)
df.head()
# Out:
#             type                  title         director date_added  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson 2021-09-25
# s2       TV Show          Blood & Water              NaN 2021-09-24
# s3       TV Show              Ganglands  Julien Leclercq 2021-09-24
# s4       TV Show  Jailbirds New Orleans              NaN 2021-09-24
# s5       TV Show           Kota Factory              NaN 2021-09-24
#
#          release_year rating  \
# show_id
# s1               2020  PG-13
# s2               2021  TV-MA
# s3               2021  TV-MA
# s4               2021  TV-MA
# s5               2021  TV-MA
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s5       In a city of coaching centers known to train I...                NaN
#
#          seasons (TV Show)
# show_id
# s1                     NaN
# s2                     2.0
# s3                     1.0
# s4                     1.0
# s5                     2.0

# %% [markdown]
# ### Création de colonnes temporelles
#
# À partir de 'Date Added', créez des colonnes pour l'année d'ajout, le mois d'ajout et le jour de la semaine d'ajout

# %%
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
df['day_added'] = df['date_added'].dt.day_name()
df.head()
# Out:
#             type                  title         director date_added  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson 2021-09-25
# s2       TV Show          Blood & Water              NaN 2021-09-24
# s3       TV Show              Ganglands  Julien Leclercq 2021-09-24
# s4       TV Show  Jailbirds New Orleans              NaN 2021-09-24
# s5       TV Show           Kota Factory              NaN 2021-09-24
#
#          release_year rating  \
# show_id
# s1               2020  PG-13
# s2               2021  TV-MA
# s3               2021  TV-MA
# s4               2021  TV-MA
# s5               2021  TV-MA
#
#                                                description  duration (movies)  \
# show_id
# s1       As her father nears the end of his life, filmm...               90.0
# s2       After crossing paths at a party, a Cape Town t...                NaN
# s3       To protect his family from a powerful drug lor...                NaN
# s4       Feuds, flirtations and toilet talk go down amo...                NaN
# s5       In a city of coaching centers known to train I...                NaN
#
#          seasons (TV Show)  year_added  month_added day_added
# show_id
# s1                     NaN      2021.0          9.0  Saturday
# s2                     2.0      2021.0          9.0    Friday
# s3                     1.0      2021.0          9.0    Friday
# s4                     1.0      2021.0          9.0    Friday
# s5                     2.0      2021.0          9.0    Friday

# %% [markdown]
# <h1> Analyse des données </h1>

# %% [markdown]
# 1) Combien de "shows" sont présents dans ce dataset ? 2) Quelle est la répartition entre les types 'Movie' et 'TV Show' ? 3) Quelle est la répartition des ajouts en fonction de l'année ? 4) Quel est le top 5 des catégories de shows les plus ajoutées ? 5) Quel est le top 5 des comédiens les plus plébiscités aux États-Unis ? 6) Quelle est la répartition des ajouts en fonction du jour de la semaine ? 7) Dans quel pays sont produits le plus de documentaires ? 8) En moyenne, combien de saisons ont les séries ? 9) Quelle est la distribution des films en fonction de leur durée (quartiles) ? 10) Combien de shows ont pour thématique la drogue (présence du mot "drug" dans la description) ?

# %%
df.index.value_counts().sum()
# Out:
# np.int64(8809)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6132
# TV Show    2677
# Name: count, dtype: int64

# %%
df['year_added'].value_counts()
# Out:
# year_added
# 2019.0    1999
# 2020.0    1878
# 2018.0    1625
# 2021.0    1498
# 2017.0    1164
# 2016.0     418
# 2015.0      73
# 2014.0      23
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2024.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# 4) Quel est le top 5 des catégories de shows les plus ajoutées ?

# %%
top_5_categories = categories_exploded['listed_in'].value_counts().head(5)
top_5_categories
# Out:
# listed_in
#  International Movies    2624
# Dramas                   1600
# Comedies                 1210
# Action & Adventure        859
# Documentaries             829
# Name: count, dtype: int64

# %% [markdown]
# Quel est le top 5 des comédiens les plus plébiscités aux États-Unis ?

# %%
us_titles = cast_list[cast_list['country'].astype(str).str.contains('United States', na=False)]
com_titles = us_titles[us_titles['listed_in'].astype(str).str.contains('Comedy', na=False)]
top_actors_us = com_titles['cast'].value_counts().head(5)
top_actors_us
# Out:
# cast
# Jeff Dunham      8
# Kevin Hart       7
# Jim Gaffigan     5
# Bill Burr        5
# Katt Williams    5
# Name: count, dtype: int64

# %% [markdown]
# Quelle est la répartition des ajouts en fonction du jour de la semaine

# %%
df['day_added'].value_counts()
# Out:
# day_added
# Friday       2478
# Thursday     1387
# Wednesday    1276
# Tuesday      1182
# Monday        845
# Saturday      803
# Sunday        740
# Name: count, dtype: int64

# %% [markdown]
# Dans quel pays sont produits le plus de documentaires ?

# %%
# Dans quel pays sont produits le plus de documentaires ?
doc_titles = countries_exploded[countries_exploded['listed_in'].astype(str).str.contains('Documentaries', na=False)]
top_country_doc = doc_titles['country'].value_counts().head(1)
top_country_doc
# Out:
# country
# United States    453
# Name: count, dtype: int64

# %% [markdown]
# En moyenne, combien de saisons ont les séries ?

# %%
nbr_sais_moy = df['seasons (TV Show)'].mean()
int(nbr_sais_moy)
# Out:
# 1

# %% [markdown]
# Quelle est la distribution des films en fonction de leur durée (quartiles)

# %%
dist_film = df[df['type'] == 'Movie']['duration (movies)']
dist_film.describe()
# Out:
# count    6129.000000
# mean       99.578887
# std        28.288598
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration (movies), dtype: float64

# %% [markdown]
# Combien de shows ont pour thématique la drogue (présence du mot "drug" dans la description) ?

# %%
show_drug = df[df['description'].str.contains('drug', na=False)]
show_drug.index.value_counts().sum()
# Out:
# np.int64(158)
